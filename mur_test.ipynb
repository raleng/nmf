# %%
import numpy as np
from misc import showme
import matplotlib.pyplot as plt
import mur

# %%
w_true = mur.normalize(np.abs(np.random.randn(10, 5)))

h_true = np.abs(np.random.randn(5, 25))

data = w_true @ h_true

# %%
mur.mur(data, 5, distance_type='eu', tol1=1e-2, tol2=1e-2)
# Out:
# INFO:root:[0]: 0.49
# WARNING:root:Converged.
# Entering Main Loop.
# Algorithm converged (2).
# Results saved in ./results/nmf.

# %%
results = np.load('results/nmf.npz')
w = results['w']
h = results['h']

# %%
plt.subplot(121)
plt.imshow(w@h)
plt.colorbar()
plt.subplot(122)
plt.imshow(data)
plt.colorbar()

# %%
plt.imshow(w@h-data)
plt.colorbar()

# %%
plt.subplot(121)
plt.plot(w)
plt.subplot(122)
plt.plot(w_true)
